# %% [markdown]
# ---
#
# ## 📘 Data Dictionary – Adult Income Dataset
#
# | Feature           | Description                                                                 | Type      | Example Categories / Values |
# |------------------|-----------------------------------------------------------------------------|-----------|------------------------------|
# | **age**           | Age of the individual                                                       | Numeric   | `39`, `50`                  |
# | **workclass**     | Type of employer or sector                                                  | Categorical | `Private`, `State-gov`, `Self-emp-inc`, `?` (unknown) |
# | **fnlwgt**        | Final sampling weight (for statistical purposes, often dropped)             | Numeric   | `77516`, `123011`           |
# | **education**     | Highest level of education attained                                         | Categorical | `Bachelors`, `HS-grad`, `Doctorate`, `Some-college` |
# | **education-num** | Numeric representation of education level                                   | Numeric   | `13`, `9`, `10`             |
# | **marital-status**| Marital status of the individual                                            | Categorical | `Never-married`, `Married-civ-spouse`, `Divorced`, `Widowed` |
# | **occupation**    | Type of job/occupation                                                      | Categorical | `Exec-managerial`, `Sales`, `?`, `Prof-specialty` |
# | **relationship**  | Relationship of individual to head of household                             | Categorical | `Husband`, `Wife`, `Own-child`, `Not-in-family` |
# | **race**          | Race of the individual                                                      | Categorical | `White`, `Black`, `Asian-Pac-Islander`, `Other` |
# | **sex**           | Gender of the individual                                                    | Categorical | `Male`, `Female`            |
# | **capital-gain**  | Income from capital gains                                                   | Numeric   | `0`, `14084`                |
# | **capital-loss**  | Income lost due to capital loss                                             | Numeric   | `0`, `1902`                 |
# | **hours-per-week**| Number of hours worked per week                                             | Numeric   | `40`, `50`                  |
# | **native-country**| Country of origin                                                           | Categorical | `United-States`, `India`, `Mexico`, `?` (unknown) |
# | **income**        | Target variable — income level                                              | Categorical | `<=50K`, `>50K`, `<=50K.`, `>50K.` |
#
# ---

# %% [markdown]
# ---
#
# ## 📘 Detailed Data Dictionary – Adult Income Dataset
#
# ### 🔢 `age`
# - Age of the individual (continuous numerical value).
#
# ---
#
# ### 🧳 `workclass`
# - Describes the type of employment.
#
# | Value                 | Meaning |
# |----------------------|---------|
# | `State-gov`          | Works for a state government agency. |
# | `Self-emp-not-inc`   | Self-employed but not incorporated (e.g., freelancer, sole proprietor). |
# | `Private`            | Works in the private sector. |
# | `Federal-gov`        | Works for the federal government. |
# | `Local-gov`          | Works for a local government (e.g., city or county). |
# | `?`                  | Unknown or missing value. |
# | `Self-emp-inc`       | Self-employed and incorporated (e.g., owns a registered business). |
# | `Without-pay`        | Works without receiving pay (e.g., volunteer). |
# | `Never-worked`       | Has never been employed. |
#
# ---
#
# ### 🎓 `education`
# - Highest level of education attained.
#
# | Value           | Meaning |
# |----------------|---------|
# | `Bachelors`         | Completed a Bachelor's degree. |
# | `HS-grad`           | High school graduate. |
# | `11th`, `9th`, `10th`, `7th-8th`, `5th-6th`, `1st-4th`, `12th` | Grade levels completed (not graduated). |
# | `Masters`           | Completed a Master's degree. |
# | `Some-college`      | Attended college but did not complete a degree. |
# | `Assoc-acdm`        | Associate degree (academic). |
# | `Assoc-voc`         | Associate degree (vocational). |
# | `Doctorate`         | Ph.D. or equivalent. |
# | `Prof-school`       | Professional school (e.g., law, medicine). |
# | `Preschool`         | Attended preschool only. |
#
# ---
#
# ### 🔢 `education-num`
# - Numerical equivalent of the education level. E.g., `Bachelors` = 13
#
# ---
#
# ### 💍 `marital-status`
# - Marital relationship of the person.
#
# | Value                 | Meaning |
# |----------------------|---------|
# | `Never-married`          | Has never been legally married. |
# | `Married-civ-spouse`     | Legally married and living with spouse. |
# | `Divorced`               | Previously married, now legally divorced. |
# | `Married-spouse-absent`  | Legally married, but spouse not living in the household. |
# | `Separated`              | Married but currently not living with spouse, possibly awaiting divorce. |
# | `Married-AF-spouse`      | Married with spouse in Armed Forces (rare). |
# | `Widowed`                | Spouse has died, not remarried. |
#
# ---
#
# ### 👷 `occupation`
# - Job type or professional role.
#
# | Value               | Meaning |
# |--------------------|---------|
# | `Adm-clerical`           | Clerical/admin roles (e.g., secretary). |
# | `Exec-managerial`        | Executive or managerial role. |
# | `Handlers-cleaners`      | Physical labor (e.g., janitors, warehouse handlers). |
# | `Prof-specialty`         | Professionally specialized (e.g., engineers, doctors). |
# | `Other-service`          | Services not listed (e.g., food service, housekeeping). |
# | `Sales`                  | Salespersons. |
# | `Craft-repair`           | Skilled trade jobs (e.g., mechanics). |
# | `Transport-moving`       | Transportation roles (e.g., truck drivers). |
# | `Farming-fishing`        | Agriculture, farming, or fishing. |
# | `Machine-op-inspct`      | Machine operators and inspectors. |
# | `Tech-support`           | Technical support roles. |
# | `?`                      | Unknown/missing occupation. |
# | `Protective-serv`        | Security personnel, police, firefighters. |
# | `Armed-Forces`           | Military service. |
# | `Priv-house-serv`        | Domestic help (e.g., maids, housekeepers). |
#
# ---
#
# ### 👨‍👩‍👧‍👦 `relationship`
# - Individual’s role in the household.
#
# | Value          | Meaning |
# |---------------|---------|
# | `Not-in-family`   | Lives alone or with non-family members. |
# | `Husband`         | Married man, head of household. |
# | `Wife`            | Married woman, head or part of household. |
# | `Own-child`       | Son/daughter of head of household. |
# | `Unmarried`       | Single, divorced, or widowed. |
# | `Other-relative`  | Other family member (e.g., cousin, parent). |
#
# ---
#
# ### 🧑‍🤝‍🧑 `race`
# - Self-identified race.
#
# | Value                  | Meaning |
# |------------------------|---------|
# | `White`                   | White/Caucasian. |
# | `Black`                   | Black/African-American. |
# | `Asian-Pac-Islander`      | Asian or Pacific Islander descent. |
# | `Amer-Indian-Eskimo`      | Native American or Alaskan Native. |
# | `Other`                   | Other or mixed race. |
#
# ---
#
# ### ⚧ `sex`
# - Gender identity.
#
# | Value   | Meaning |
# |---------|---------|
# | `Male`     | Man |
# | `Female`   | Woman |
#
# ---
#
# ### 💰 `capital-gain` & `capital-loss`
# - Financial gain or loss from investment-related activity (numeric).
#
# ---
#
# ### 🕓 `hours-per-week`
# - Hours worked per week (numeric).
#
# ---
#
# ### 🌎 `native-country`
# - Country of origin.
#
# > Contains countries like `United-States`, `India`, `Mexico`, `Philippines`, `Vietnam`, `?` (missing).
#
# ---
#
# ### 💼 `income` (Target)
# - Income bracket (classification target).
#
#
# -`>50K` / `>50K.`   ==>  Earns more than $50,000 per year.
#
#  `<=50K` / `<=50K.` ==> Earns $50,000 or less per year.
#
# ---
